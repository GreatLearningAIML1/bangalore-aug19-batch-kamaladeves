# %% [markdown]
# ## Supervised Learning - Building a Student Performace Prediction System

# %% [markdown]
# ## Question 1 - Classification vs. Regression
#
# *The aim of this project is to predict how likely a student is to pass. Which type of supervised learning problem is this, classification or regression? Why?*
#
# #### Answer:
# This project is a classification supervised learning problem because the variable to predict, i.e. if a student graduates or fails to graduate, is categorical. On this case this a dichotomous categorical variable where the only two possible values are "pass" or "fail".

# %% [markdown]
# ### Overview:
#
# 1.Read the problem statement.
#
# 2.Get the dataset.
#
# 3.Explore the dataset.
#
# 4.Pre-processing of dataset.
#
# 5.Transform the dataset for building machine learning model.
#
# 6.Split data into train, test set.
#
# 7.Build Model.
#
# 8.Apply the model.
#
# 9.Evaluate the model.
#
# 10.Provide insights.

# %% [markdown]
# ## Problem Statement
#
# Using Logistic Regression **predict the performance of student**. The classification goal is to predict whether the student will pass or fail.
#
# ## Dataset
#
# This data approach student achievement in secondary education of two Portuguese schools. The data attributes include student grades, demographic, social and school related features) and it was collected by using school reports and questionnaires. Two datasets are provided regarding the performance in Mathematics.
#
# **Source:** https://archive.ics.uci.edu/ml/datasets/Student+Performance

# %% [markdown]
# ## Question 2
# ## Exploring the Data
# *Read the dataset file using pandas. Take care about the delimiter.*
#
# #### Answer:

# %%
import pandas as pd
import numpy as np
st_df = pd.read_csv('students-data.csv',delimiter=';')

# %%
st_df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# ...

# %% [markdown]
# ## Question 3
# ## Drop missing values
# *Set the index name of the dataframe to **"number"**. Check sample of data to drop if any missing values are there.*
#
# #### Answer:

# %%
st_df.index.names = ['number']
st_df.head(50)
st_df.isnull()
st_df.dropna()
# Out:
#        school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# number
# 0          GP   F   18       U     GT3       A     4     4   at_home
# 1          GP   F   17       U     GT3       T     1     1   at_home
# 2          GP   F   15       U     LE3       T     1     1   at_home
# 3          GP   F   15       U     GT3       T     4     2    health
# 4          GP   F   16       U     GT3       T     3     3     other
# 5          GP   M   16       U     LE3       T     4     3  services
# 6          GP   M   16       U     LE3       T     2     2     other
# 7          GP   F   17       U     GT3       A     4     4     other
# 8          GP   M   15       U     LE3       A     3     2  services
# 9          GP   M   15       U     GT3       T     3     4     other
# 10         GP   F   15       U     GT3       T     4     4   teacher
# 11         GP   F   15       U     GT3       T     2     1  services
# ...

# %% [markdown]
# ## Transform Data
#
# *Print all the attribute names which are not numerical.*
#
# **Hint:** check **select_dtypes()** and its **include** and **exclude** parameters.**
#
# #### Answer:

# %%
st_df.dtypes
st_df.select_dtypes(exclude = 'int64')
st_df.select_dtypes(include = 'object')
# Out:
#        school sex address famsize Pstatus      Mjob      Fjob      reason  \
# number
# 0          GP   F       U     GT3       A   at_home   teacher      course
# 1          GP   F       U     GT3       T   at_home     other      course
# 2          GP   F       U     LE3       T   at_home     other       other
# 3          GP   F       U     GT3       T    health  services        home
# 4          GP   F       U     GT3       T     other     other        home
# 5          GP   M       U     LE3       T  services     other  reputation
# 6          GP   M       U     LE3       T     other     other        home
# 7          GP   F       U     GT3       A     other   teacher        home
# 8          GP   M       U     LE3       A  services     other        home
# 9          GP   M       U     GT3       T     other     other        home
# 10         GP   F       U     GT3       T   teacher    health  reputation
# 11         GP   F       U     GT3       T  services     other  reputation
# ...

# %% [markdown]
# ## Drop variables with less variance
#
# *Find the variance of each numerical independent variable and drop whose variance is less than 1.*

# %%
st_df.select_dtypes(include = 'int64').head(5)
# Out:
#         age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  \
# number
# 0        18     4     4           2          2         0       4         3
# 1        17     1     1           1          2         0       5         3
# 2        15     1     1           1          2         3       4         3
# 3        15     4     2           1          3         0       3         2
# 4        16     3     3           1          2         0       4         3
#
#         goout  Dalc  Walc  health  absences  G1  G2  G3
# number
# 0           4     1     1       3         6   5   6   6
# 1           3     1     1       3         4   5   5   6
# 2           2     2     3       3        10   7   8  10
# 3           2     1     1       5         2  15  14  15
# 4           2     1     2       5         4   6  10  10

# %%
import statistics as stats
stats.variance(st_df['age'])
stats.variance(st_df['Medu'])
stats.variance(st_df['Fedu'])
stats.variance(st_df['traveltime'])
stats.variance(st_df['studytime'])
stats.variance(st_df['failures'])
stats.variance(st_df['famrel'])
stats.variance(st_df['freetime'])
stats.variance(st_df['goout'])
stats.variance(st_df['Dalc'])
stats.variance(st_df['Walc'])
stats.variance(st_df['health'])
stats.variance(st_df['absences'])
stats.variance(st_df['G1'])
stats.variance(st_df['G2'])
stats.variance(st_df['G3'])
# Out:
# 20.989616397866737

# %%
# dropping traveltime,studytime,failures,famrel,'freetime',dalc,absences as they have variance less than 1
st_df2 = st_df.drop(['traveltime','studytime','failures','famrel','freetime','Dalc','absences'], axis=1)
st_df2.head(5)
# Out:
#        school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# number
# 0          GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1          GP   F   17       U     GT3       T     1     1  at_home     other
# 2          GP   F   15       U     LE3       T     1     1  at_home     other
# 3          GP   F   15       U     GT3       T     4     2   health  services
# 4          GP   F   16       U     GT3       T     3     3    other     other
#
#         ... nursery higher internet romantic goout Walc health  G1  G2  G3
# number  ...
# 0       ...     yes    yes       no       no     4    1      3   5   6   6
# 1       ...      no    yes      yes       no     3    1      3   5   5   6
# 2       ...     yes    yes      yes       no     2    3      3   7   8  10
# 3       ...     yes    yes      yes      yes     2    1      5  15  14  15
# 4       ...     yes    yes       no       no     2    2      5   6  10  10
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Question 4 - Encode all categorical variables to numerical
#
# Take the list of categorical attributes(from the above result) and convert them into neumerical variables. After that, print the head of dataframe and check the values.
#
# **Hint:** check **sklearn LabelEncoder()**
#
# #### Answer:

# %%
st_df2.select_dtypes(include ='object').head(3)
# Out:
#        school sex address famsize Pstatus     Mjob     Fjob  reason guardian  \
# number
# 0          GP   F       U     GT3       A  at_home  teacher  course   mother
# 1          GP   F       U     GT3       T  at_home    other  course   father
# 2          GP   F       U     LE3       T  at_home    other   other   mother
#
#        schoolsup famsup paid activities nursery higher internet romantic
# number
# 0            yes     no   no         no     yes    yes       no       no
# 1             no    yes   no         no      no    yes      yes       no
# 2            yes     no  yes         no     yes    yes      yes       no

# %%
from sklearn import preprocessing 
label_encoder = preprocessing.LabelEncoder() 
st_df2['school']= label_encoder.fit_transform(st_df2['school']) 
st_df2['sex']= label_encoder.fit_transform(st_df2['sex']) 
st_df2['address']= label_encoder.fit_transform(st_df2['address']) 
st_df2['famsize']= label_encoder.fit_transform(st_df2['famsize']) 
st_df2['Pstatus']= label_encoder.fit_transform(st_df2['Pstatus']) 
st_df2['Mjob']= label_encoder.fit_transform(st_df2['Mjob']) 
st_df2['Fjob']= label_encoder.fit_transform(st_df2['Fjob']) 
st_df2['reason']= label_encoder.fit_transform(st_df2['reason']) 
st_df2['guardian']= label_encoder.fit_transform(st_df2['guardian']) 
st_df2['schoolsup']= label_encoder.fit_transform(st_df2['schoolsup']) 
st_df2['famsup']= label_encoder.fit_transform(st_df2['famsup']) 
st_df2['paid']= label_encoder.fit_transform(st_df2['paid']) 
st_df2['activities']= label_encoder.fit_transform(st_df2['activities']) 
st_df2['nursery']= label_encoder.fit_transform(st_df2['nursery']) 
st_df2['school']= label_encoder.fit_transform(st_df2['school']) 
st_df2['higher']= label_encoder.fit_transform(st_df2['higher']) 
st_df2['internet']= label_encoder.fit_transform(st_df2['internet']) 
st_df2['romantic']= label_encoder.fit_transform(st_df2['romantic']) 
st_df2.head(3)
# Out:
#         school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  \
# number
# 0            0    0   18        1        0        0     4     4     0     4
# 1            0    0   17        1        0        1     1     1     0     2
# 2            0    0   15        1        1        1     1     1     0     2
#
#         ...  nursery  higher  internet  romantic  goout  Walc  health  G1  G2  \
# number  ...
# 0       ...        1       1         0         0      4     1       3   5   6
# 1       ...        0       1         1         0      3     1       3   5   5
# 2       ...        1       1         1         0      2     3       3   7   8
#
#         G3
# number
# 0        6
# 1        6
# 2       10
#
# [3 rows x 26 columns]

# %% [markdown]
# ## Question 5 - Convert the continuous values of grades into classes
#
# *Consider the values in G1, G2 and G3 with >= 10 as pass(1) and < 10 as fail(0) and encode them into binary values. Print head of dataframe to check the values.*
#
# #### Answer:

# %%
st_df
st_df2['G1'] = st_df['G1']
st_df3 = st_df2
st_df3['G1'] = st_df3['G1']>=10
st_df3['G2'] = st_df3['G2']>=10
st_df3['G3'] = st_df3['G3']>=10
mask = st_df3.applymap(type) != bool
d = {True: 'TRUE', False: 'FALSE'}
st_df3 = st_df3.where(mask, st_df3.replace(d))
st_df3['G1'] = st_df3['G1'].replace('TRUE',1)
st_df3['G1'] = st_df3['G1'].replace('FALSE',0)
st_df3['G2'] = st_df3['G2'].replace('FALSE',0)
st_df3['G2'] = st_df3['G2'].replace('TRUE',1)
st_df3['G3'] = st_df3['G3'].replace('FALSE',0)
st_df3['G3'] = st_df3['G3'].replace('TRUE',1)
st_df3.head(10)
# Out:
#         school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  \
# number
# 0            0    0   18        1        0        0     4     4     0     4
# 1            0    0   17        1        0        1     1     1     0     2
# 2            0    0   15        1        1        1     1     1     0     2
# 3            0    0   15        1        0        1     4     2     1     3
# 4            0    0   16        1        0        1     3     3     2     2
# 5            0    1   16        1        1        1     4     3     3     2
# 6            0    1   16        1        1        1     2     2     2     2
# 7            0    0   17        1        0        0     4     4     2     4
# 8            0    1   15        1        1        0     3     2     3     2
# 9            0    1   15        1        0        1     3     4     2     2
#
#         ...  nursery  higher  internet  romantic  goout  Walc  health  G1  G2  \
# number  ...
# ...

# %% [markdown]
# ## Question 6
# *Consider G3 is the target attribute and remaining all attributes as features to predict G3. Now, separate features and target into separate dataframes and name them X and y respectively.*

# %%
X = pd.DataFrame(st_df3.iloc[:,0:25])

# %%
y = pd.DataFrame(st_df3['G3'])

# %% [markdown]
# ## Visualization
#
# ## Question 7
#
# *Plot G2 and G3 and give your understanding on relation between both variables.*

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
a = st_df['G3']
b = st_df['G2']
matplotlib.style.use('ggplot')
plt.scatter(a,b)
plt.show()

# %% [markdown]
# The G3 depends a great deal on the G2. Thus, the G2 can be a good predictor of the outcome variable.

# %% [markdown]
# ## Question 8
#
# *Plot the number of students in each school and number of students with different ages in separate plots.*

# %%
sns.distplot(st_df2['school'], kde=False, rug=True)

# %%
sns.distplot(st_df2['age'], kde=False, rug=True)

# %% [markdown]
# ## Question 9 - Training and testing data split

# %% [markdown]
# *So far, you have converted all categorical features into numeric values. Now, split the data into training and test sets with training size of 300 records. Print the number of train and test records.*
#
# **Hint:** check **train_test_split()** from **sklearn**
#
# #### Answer:

# %%
from sklearn import model_selection
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
test_size = 300
seed = 8
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=test_size, random_state=seed)

# %% [markdown]
# ## Question 10 - Model Implementation and Testing the Accuracy
#
# *Build a **LogisticRegression** classifier using **fit()** and **predict()** functions in sklearn. Print Accuracy and F1 score of Training and Test sets.*
#
# #### Answer:

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
y_predict = model.predict(X_test)
model_score = model.score(X_test, y_test)
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Lenovo\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
print(model_score)
print(metrics.confusion_matrix(y_test, y_predict))
# Out:
# 0.87
# [[ 76  25]
#  [ 14 185]]

# %%
from sklearn.metrics import f1_score
f1_score(y_test, y_predict, average='weighted')
# Out:
# 0.8680047107617864

# %% [markdown]
# # Naive bayes with Iris data

# %% [markdown]
# ### Import Iris.csv

# %%
import pandas as pd
import numpy as np
iris_df = pd.read_csv('iris.csv')
iris_df.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris_df1 = pd.DataFrame(iris_df.drop(['Id'],axis=1))

# %%
iris_df1.head(3)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa

# %%
iris_df1.isnull()
iris_df1['SepalLengthCm'].fillna(iris_df1['SepalLengthCm'].median(), inplace = True)
iris_df1['SepalWidthCm'].fillna(iris_df1['SepalWidthCm'].median(), inplace = True)
iris_df1['PetalLengthCm'].fillna(iris_df1['PetalLengthCm'].median(), inplace = True)
iris_df1['PetalWidthCm'].fillna(iris_df1['PetalWidthCm'].median(), inplace = True)

# %% [markdown]
# ### Slice data set for Independent variables and dependent variables
# #### Please note 'Species' is my dependent variables, name it y and independent set data as X

# %%
X = pd.DataFrame(iris_df1.iloc[:,0:3])
y = pd.DataFrame(iris_df1['Species'])

# %% [markdown]
# ### Find the distribution of target variable (Class)

# %%
pd.value_counts(iris_df["Species"]).plot(kind="line")

# %% [markdown]
# ### Plot the distribution of target variable using histogram

# %%
pd.value_counts(iris_df["Species"]).plot(kind="bar")

# %% [markdown]
# ### Plot Scatter Matrix to understand the distribution of variables and give insights from it( 1 Marks)

# %%
import seaborn as sns
sns.pairplot(iris_df1, hue="Species")

# %%
#irise setosa seems to have a distinct pattern with repect to the other two classes
#There seems to be linear relationship between petalwidth and petal length for versicolor and virginica but setosa is distinct.
#here seems to be linear relationship between petallength and sepal length for versicolor and virginica but setosa is distinct.

# %% [markdown]
# ### Summary Statistics and explain insights for at least 2 variables

# %%
iris_df1.describe().transpose()
# Out:
#                count      mean       std  min  25%   50%  75%  max
# SepalLengthCm  152.0  5.843421  0.822584  4.3  5.1  5.80  6.4  7.9
# SepalWidthCm   152.0  3.053289  0.430757  2.0  2.8  3.00  3.3  4.4
# PetalLengthCm  152.0  3.766447  1.754000  1.0  1.6  4.35  5.1  6.9
# PetalWidthCm   152.0  1.203289  0.759698  0.1  0.3  1.30  1.8  2.5

# %%
#The feature Petal length has standard deviation more than one ;while the mean value and median value for all other features approximately the same,there is variation in petal length alone.
#The sepal width feature which is the feature with minimum std does not seem to vary much in the entire data set, though from the pairplot we can infer that iris setosa alone is distinct

# %% [markdown]
# ### Correlation among all variables and give your insights

# %%
iris = iris_df1.corr()
sns.heatmap(iris)
#sepal length and sepal width are positively corelated
#Reasonable corelation between sepal width and petal length
#Reasonable corelation between sepal width and petal width

# %% [markdown]
# ### Split data in Training and Validation in 80:20

# %%
from sklearn import model_selection
from sklearn import metrics
from sklearn.model_selection import train_test_split
test_size = 0.20
seed = 8 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=seed)

# %% [markdown]
# ### Do Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler() 
scaler.fit(X, y = None)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %% [markdown]
# ### Train and Fit NaiveBayes Model

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GaussianNB(priors=None, var_smoothing=1e-09)

# %% [markdown]
# ### Print Accuracy and Confusion Matrix and Conclude your findings

# %%
expected = y_test
predicted = model.predict(X_test)
print(metrics.classification_report(expected, predicted))
print(metrics.confusion_matrix(expected, predicted))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       0.75      0.67      0.71         9
#  Iris-virginica       0.75      0.82      0.78        11
#
#        accuracy                           0.84        31
#       macro avg       0.83      0.83      0.83        31
#    weighted avg       0.84      0.84      0.84        31
#
# [[11  0  0]
#  [ 0  6  3]
#  [ 0  2  9]]

# %%
#The model works with overall accuracy of 84%
#The model is able to predict iris setosa correctly with 100% accuracy as it had distinctive features
#The model is able to predict 6/9 versicolor and 9/11 virginica correctly; model is unable to classify these two sets as accurately as setosa because they have features with high similarity.
#The precision for versicolor and virginica are same but the recall metric of versicolor is poor compared to virginica; so the model performs poorly in identifying versicolor.
